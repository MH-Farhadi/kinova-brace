# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import torch
import torch.nn as nn
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
from stable_baselines3.common.callbacks import BaseCallback
import pygame
import math
import time
import matplotlib.pyplot as plt
import os

# Constants
FULL_VIEW_SIZE = (1200, 800)
MAX_SPEED = 3
DOT_RADIUS = 30
TARGET_RADIUS = 10
GOAL_DETECTION_RADIUS = DOT_RADIUS + TARGET_RADIUS
START_POS = [FULL_VIEW_SIZE[0] // 2, FULL_VIEW_SIZE[1] // 2]
NOISE_MAGNITUDE = 0.5  # Match the game's noise level

# Colors
WHITE = (255, 255, 255)
BLACK = (0, 0, 0)
RED = (255, 0, 0)
GREEN = (0, 200, 0)
BLUE = (0, 0, 255)
YELLOW = (255, 255, 0)

class CustomFeaturesExtractor(BaseFeaturesExtractor):
    def __init__(self, observation_space: gym.spaces.Box, features_dim: int = 64):
        super().__init__(observation_space, features_dim)
        
        n_input = int(np.prod(observation_space.shape))
        
        self.network = nn.Sequential(
            nn.Linear(n_input, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, features_dim),
            nn.ReLU()
        )
        
    def forward(self, observations: torch.Tensor) -> torch.Tensor:
        return self.network(observations)

class MetricsCallback(BaseCallback):
    def __init__(self, verbose=0):
        super().__init__(verbose)
        self.episode_rewards = []
        self.episode_lengths = []
        self.episode_gammas = []
        self.training_losses = []
        self.current_episode_gammas = []
        self.total_reward = 0
        
    def _on_step(self):
        # Get info from current step
        info = self.locals['infos'][0]
        gamma = float(self.locals['actions'][0])
        self.current_episode_gammas.append(gamma)
        self.total_reward += self.locals['rewards'][0]
        
        # Check if episode is done
        if self.locals['dones'][0]:
            self.episode_rewards.append(self.total_reward)
            self.episode_lengths.append(len(self.current_episode_gammas))
            self.episode_gammas.append(np.mean(self.current_episode_gammas))
            
            # Reset episode-specific metrics
            self.current_episode_gammas = []
            self.total_reward = 0
            
            # Store training loss if available
            if hasattr(self.model, 'logger') and 'train/loss' in self.model.logger.name_to_value:
                self.training_losses.append(self.model.logger.name_to_value['train/loss'])
        
        return True

    def plot_metrics(self, save_dir="training_metrics"):
        """Plot and save training metrics."""
        os.makedirs(save_dir, exist_ok=True)
        
        # Plot episode rewards
        plt.figure(figsize=(10, 6))
        plt.plot(self.episode_rewards)
        plt.title('Episode Rewards Over Time')
        plt.xlabel('Episode')
        plt.ylabel('Total Reward')
        plt.grid(True)
        plt.savefig(os.path.join(save_dir, 'episode_rewards.png'))
        plt.close()
        
        # Plot episode lengths
        plt.figure(figsize=(10, 6))
        plt.plot(self.episode_lengths)
        plt.title('Episode Lengths Over Time')
        plt.xlabel('Episode')
        plt.ylabel('Steps')
        plt.grid(True)
        plt.savefig(os.path.join(save_dir, 'episode_lengths.png'))
        plt.close()
        
        # Plot average gamma values
        plt.figure(figsize=(10, 6))
        plt.plot(self.episode_gammas)
        plt.title('Average Gamma Values Per Episode')
        plt.xlabel('Episode')
        plt.ylabel('Average Gamma')
        plt.grid(True)
        plt.savefig(os.path.join(save_dir, 'episode_gammas.png'))
        plt.close()
        
        # Plot training loss if available
        if self.training_losses:
            plt.figure(figsize=(10, 6))
            plt.plot(self.training_losses)
            plt.title('Training Loss Over Time')
            plt.xlabel('Update')
            plt.ylabel('Loss')
            plt.grid(True)
            plt.savefig(os.path.join(save_dir, 'training_loss.png'))
            plt.close()
        
        # Plot moving averages
        window = 100
        if len(self.episode_rewards) > window:
            plt.figure(figsize=(10, 6))
            rewards_ma = np.convolve(self.episode_rewards, 
                                   np.ones(window)/window, 
                                   mode='valid')
            plt.plot(rewards_ma)
            plt.title(f'Moving Average of Rewards (Window={window})')
            plt.xlabel('Episode')
            plt.ylabel('Average Reward')
            plt.grid(True)
            plt.savefig(os.path.join(save_dir, 'rewards_moving_average.png'))
            plt.close()
        
        # Save summary statistics
        with open(os.path.join(save_dir, 'training_summary.txt'), 'w') as f:
            f.write(f"Total Episodes: {len(self.episode_rewards)}\n")
            f.write(f"Average Reward: {np.mean(self.episode_rewards):.2f}\n")
            f.write(f"Average Episode Length: {np.mean(self.episode_lengths):.2f}\n")
            f.write(f"Average Gamma: {np.mean(self.episode_gammas):.2f}\n")
            f.write(f"Final 100 Episodes Average Reward: {np.mean(self.episode_rewards[-100:]):.2f}\n")
            f.write(f"Best Episode Reward: {np.max(self.episode_rewards):.2f}\n")
            f.write(f"Worst Episode Reward: {np.min(self.episode_rewards):.2f}\n")

class DynamicArbitrationEnv(gym.Env):
    def __init__(self, render_mode=None):
        super().__init__()
        self.render_mode = render_mode
        
        if render_mode == "human":
            pygame.init()
            self.screen = pygame.display.set_mode(FULL_VIEW_SIZE)
            pygame.display.set_caption("Training Visualization")
            self.font = pygame.font.Font(None, 24)
        
        # Observation space: [dot_pos_x, dot_pos_y, human_input_x, human_input_y, 
        #                    target_pos_x, target_pos_y, perfect_dir_x, perfect_dir_y]
        self.observation_space = spaces.Box(
            low=np.array([0, 0, -1, -1, 0, 0, -1, -1]),
            high=np.array([FULL_VIEW_SIZE[0], FULL_VIEW_SIZE[1], 1, 1,
                          FULL_VIEW_SIZE[0], FULL_VIEW_SIZE[1], 1, 1]),
            dtype=np.float32
        )
        
        # Action space: gamma value between 0 and 1
        self.action_space = spaces.Box(
            low=np.array([0]),
            high=np.array([1]),
            dtype=np.float32
        )
        
        self.dot_pos = None
        self.target_pos = None
        self.step_count = 0
        self.max_steps = 300  # Shorter episodes for faster learning
        self.last_render_time = time.time()

    def _generate_target(self):
        # Simple random target generation
        x = np.random.uniform(100, FULL_VIEW_SIZE[0]-100)
        y = np.random.uniform(100, FULL_VIEW_SIZE[1]-100)
        return np.array([x, y], dtype=np.float32)

    def _get_obs(self):
        # Calculate perfect direction to target
        to_target = self.target_pos - self.dot_pos
        dist = np.linalg.norm(to_target)
        perfect_dir = to_target / dist if dist > 0 else np.array([0, 0])
        
        # Add noise to perfect direction to simulate human input
        noise = np.random.normal(0, NOISE_MAGNITUDE, size=2)
        human_input = perfect_dir + noise
        human_input = human_input / np.linalg.norm(human_input) if np.linalg.norm(human_input) > 0 else np.array([0, 0])
        
        return np.concatenate([
            self.dot_pos,
            human_input,
            self.target_pos,
            perfect_dir
        ])

    def reset(self, seed=None):
        super().reset(seed=seed)
        self.dot_pos = np.array(START_POS, dtype=np.float32)
        self.target_pos = self._generate_target()
        self.step_count = 0
        return self._get_obs(), {}

    def step(self, action):
        self.step_count += 1
        gamma = float(action[0])
        
        obs = self._get_obs()
        human_input = obs[2:4]
        perfect_dir = obs[6:8]
        
        # Combine directions
        combined_dir = gamma * perfect_dir + (1 - gamma) * human_input
        if np.linalg.norm(combined_dir) > 0:
            combined_dir = combined_dir / np.linalg.norm(combined_dir)
        
        # Move
        move_speed = combined_dir * MAX_SPEED
        new_pos = self.dot_pos + move_speed
        self.dot_pos = np.clip(new_pos, [0, 0], [FULL_VIEW_SIZE[0], FULL_VIEW_SIZE[1]])
        
        # Calculate reward
        dist_to_target = np.linalg.norm(self.target_pos - self.dot_pos)
        progress_reward = -dist_to_target / np.sqrt(FULL_VIEW_SIZE[0]**2 + FULL_VIEW_SIZE[1]**2)
        
        # Simplified reward structure
        reward = progress_reward
        
        # Check if done
        done = False
        if dist_to_target < GOAL_DETECTION_RADIUS:
            done = True
            reward += 5.0  # Bonus for reaching target
        elif self.step_count >= self.max_steps:
            done = True
        
        # Render if needed
        if self.render_mode == "human":
            self.render(human_input, perfect_dir, combined_dir, gamma, reward)
        
        return self._get_obs(), reward, done, False, {}

    def render(self, human_input, perfect_dir, combined_dir, gamma, reward):
        current_time = time.time()
        if current_time - self.last_render_time < 1/60:
            return
        self.last_render_time = current_time
        
        self.screen.fill(WHITE)
        
        # Draw target
        pygame.draw.circle(self.screen, YELLOW, 
                         (int(self.target_pos[0]), int(self.target_pos[1])), 
                         TARGET_RADIUS)
        
        # Draw dot
        pygame.draw.circle(self.screen, BLACK, 
                         (int(self.dot_pos[0]), int(self.dot_pos[1])), 
                         DOT_RADIUS, 2)
        
        # Draw info text
        texts = [
            f"Step: {self.step_count}",
            f"Gamma: {gamma:.2f}",
            f"Reward: {reward:.2f}"
        ]
        
        for i, text in enumerate(texts):
            text_surface = self.font.render(text, True, BLACK)
            self.screen.blit(text_surface, (10, 10 + i*25))
        
        pygame.display.flip()

def train():
    # Create and wrap the environment
    env = DynamicArbitrationEnv(render_mode="human")
    env = DummyVecEnv([lambda: env])
    
    # Create metrics callback
    metrics_callback = MetricsCallback()
    
    # Policy settings
    policy_kwargs = dict(
        features_extractor_class=CustomFeaturesExtractor,
        features_extractor_kwargs=dict(features_dim=64),
        net_arch=[dict(pi=[64, 64], vf=[64, 64])]
    )
    
    # Create and train the model
    model = PPO(
        "MlpPolicy",
        env,
        learning_rate=3e-4,
        n_steps=2048,
        batch_size=64,
        n_epochs=10,
        gamma=0.99,
        policy_kwargs=policy_kwargs,
        device='cpu',
        verbose=1
    )
    
    try:
        print("Starting training...")
        model.learn(
            total_timesteps=500_000,
            callback=metrics_callback
        )
        print("Training complete!")
        
        # Plot and save metrics
        print("Generating training metrics plots...")
        metrics_callback.plot_metrics()
        
        # Save the model
        model.save("dynamic_arbitration_ppo")
        print("Model saved!")
        
    except KeyboardInterrupt:
        print("\nTraining interrupted. Saving current model and metrics...")
        model.save("dynamic_arbitration_ppo_interrupted")
        metrics_callback.plot_metrics("training_metrics_interrupted")
    finally:
        pygame.quit()

if __name__ == "__main__":
    train()
# Out:
# Using cpu device
# c:\Users\mhfar\anaconda3\lib\site-packages\stable_baselines3\common\policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
# Starting training...
# C:\Users\mhfar\AppData\Local\Temp\ipykernel_4556\2012872152.py:64: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   gamma = float(self.locals['actions'][0])
# -----------------------------
# | time/              |      |
# |    fps             | 2097 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1003         |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0020793537 |
# |    clip_fraction        | 0.00479      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.0187      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.356        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000614    |
# |    std                  | 0.993        |
# |    value_loss           | 2.57         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 887          |
# |    iterations           | 3            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0057869796 |
# |    clip_fraction        | 0.0375       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.724        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.4          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00424     |
# |    std                  | 0.99         |
# |    value_loss           | 1.25         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 829         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.004453061 |
# |    clip_fraction        | 0.0315      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.88        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.664       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00256    |
# |    std                  | 0.983       |
# |    value_loss           | 1.43        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 800          |
# |    iterations           | 5            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0012692504 |
# |    clip_fraction        | 0.00142      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.927        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.59         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00104     |
# |    std                  | 0.981        |
# |    value_loss           | 1.25         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 780          |
# |    iterations           | 6            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0011179659 |
# |    clip_fraction        | 0.0178       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.936        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.683        |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00101     |
# |    std                  | 0.978        |
# |    value_loss           | 1.24         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 758          |
# |    iterations           | 7            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0019048823 |
# |    clip_fraction        | 0.00786      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.941        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.491        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000409    |
# |    std                  | 0.968        |
# |    value_loss           | 1.05         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 741          |
# |    iterations           | 8            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0015844081 |
# |    clip_fraction        | 0.00889      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.959        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.378        |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00167     |
# |    std                  | 0.981        |
# |    value_loss           | 1.06         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 730          |
# |    iterations           | 9            |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0025647108 |
# |    clip_fraction        | 0.0163       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.965        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.374        |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0026      |
# |    std                  | 0.968        |
# |    value_loss           | 1.24         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 724         |
# |    iterations           | 10          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.002415327 |
# |    clip_fraction        | 0.0132      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.579       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00061    |
# |    std                  | 0.971       |
# |    value_loss           | 1.16        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 719          |
# |    iterations           | 11           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0039121467 |
# |    clip_fraction        | 0.02         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.947        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.614        |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00257     |
# |    std                  | 0.975        |
# |    value_loss           | 0.857        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 712          |
# |    iterations           | 12           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0030177403 |
# |    clip_fraction        | 0.0348       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.969        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.279        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00168     |
# |    std                  | 0.977        |
# |    value_loss           | 0.792        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 706          |
# |    iterations           | 13           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0036183903 |
# |    clip_fraction        | 0.0432       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.963        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.286        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00269     |
# |    std                  | 0.958        |
# |    value_loss           | 0.802        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 700          |
# |    iterations           | 14           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0040808776 |
# |    clip_fraction        | 0.0503       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.963        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.323        |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00334     |
# |    std                  | 0.952        |
# |    value_loss           | 0.687        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 694         |
# |    iterations           | 15          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.004451165 |
# |    clip_fraction        | 0.0521      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.287       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00341    |
# |    std                  | 0.941       |
# |    value_loss           | 0.621       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 691          |
# |    iterations           | 16           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0051755323 |
# |    clip_fraction        | 0.0497       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.97         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.381        |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0033      |
# |    std                  | 0.94         |
# |    value_loss           | 0.787        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 689         |
# |    iterations           | 17          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.005499311 |
# |    clip_fraction        | 0.0468      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.281       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00117    |
# |    std                  | 0.972       |
# |    value_loss           | 0.661       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 688         |
# |    iterations           | 18          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.005522075 |
# |    clip_fraction        | 0.0531      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.438       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.000251   |
# |    std                  | 0.973       |
# |    value_loss           | 0.655       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 681          |
# |    iterations           | 19           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0035813497 |
# |    clip_fraction        | 0.0589       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.977        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.221        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000893    |
# |    std                  | 0.969        |
# |    value_loss           | 0.525        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 677         |
# |    iterations           | 20          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.005033803 |
# |    clip_fraction        | 0.0313      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.213       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00235    |
# |    std                  | 0.956       |
# |    value_loss           | 0.554       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 670          |
# |    iterations           | 21           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0030039905 |
# |    clip_fraction        | 0.0322       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.983        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.357        |
# |    n_updates            | 200          |
# |    policy_gradient_loss | 0.000702     |
# |    std                  | 0.952        |
# |    value_loss           | 0.53         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 663        |
# |    iterations           | 22         |
# |    time_elapsed         | 67         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.00488515 |
# |    clip_fraction        | 0.0494     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.36      |
# |    explained_variance   | 0.981      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.267      |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0015    |
# |    std                  | 0.924      |
# |    value_loss           | 0.445      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 654         |
# |    iterations           | 23          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.007109643 |
# |    clip_fraction        | 0.0516      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.224       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00354    |
# |    std                  | 0.929       |
# |    value_loss           | 0.509       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 650         |
# |    iterations           | 24          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.005986091 |
# |    clip_fraction        | 0.0692      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.145       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00383    |
# |    std                  | 0.934       |
# |    value_loss           | 0.385       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 647         |
# |    iterations           | 25          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.004307524 |
# |    clip_fraction        | 0.0414      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.164       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.000553    |
# |    std                  | 0.94        |
# |    value_loss           | 0.395       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 643         |
# |    iterations           | 26          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.004327785 |
# |    clip_fraction        | 0.0413      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.2         |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00192    |
# |    std                  | 0.923       |
# |    value_loss           | 0.457       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 640          |
# |    iterations           | 27           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0058881817 |
# |    clip_fraction        | 0.0542       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.985        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.223        |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00249     |
# |    std                  | 0.915        |
# |    value_loss           | 0.41         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 638         |
# |    iterations           | 28          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.005347382 |
# |    clip_fraction        | 0.0603      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.193       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.000937   |
# |    std                  | 0.91        |
# |    value_loss           | 0.445       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 637          |
# |    iterations           | 29           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0034022825 |
# |    clip_fraction        | 0.0329       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.982        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.149        |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00288     |
# |    std                  | 0.903        |
# |    value_loss           | 0.447        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 636          |
# |    iterations           | 30           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0036093525 |
# |    clip_fraction        | 0.0428       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.169        |
# |    n_updates            | 290          |
# |    policy_gradient_loss | 0.000903     |
# |    std                  | 0.898        |
# |    value_loss           | 0.35         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 634         |
# |    iterations           | 31          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.004102828 |
# |    clip_fraction        | 0.0371      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.172       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00121    |
# |    std                  | 0.896       |
# |    value_loss           | 0.347       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 633          |
# |    iterations           | 32           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0053541865 |
# |    clip_fraction        | 0.0493       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.323        |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00187     |
# |    std                  | 0.896        |
# |    value_loss           | 0.313        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 633         |
# |    iterations           | 33          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.004725729 |
# |    clip_fraction        | 0.0523      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.118       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00203    |
# |    std                  | 0.886       |
# |    value_loss           | 0.376       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 633        |
# |    iterations           | 34         |
# |    time_elapsed         | 109        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.00821213 |
# |    clip_fraction        | 0.0931     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.3       |
# |    explained_variance   | 0.986      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.115      |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.000813  |
# |    std                  | 0.9        |
# |    value_loss           | 0.321      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 632         |
# |    iterations           | 35          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.006927531 |
# |    clip_fraction        | 0.0537      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.107       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 2.62e-05    |
# |    std                  | 0.893       |
# |    value_loss           | 0.381       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 626          |
# |    iterations           | 36           |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0059031853 |
# |    clip_fraction        | 0.0623       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.987        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.216        |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00104     |
# |    std                  | 0.885        |
# |    value_loss           | 0.32         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 624         |
# |    iterations           | 37          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.007541606 |
# |    clip_fraction        | 0.0664      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.162       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.000613    |
# |    std                  | 0.896       |
# |    value_loss           | 0.304       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 623         |
# |    iterations           | 38          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.006233808 |
# |    clip_fraction        | 0.059       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.072       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.000666   |
# |    std                  | 0.869       |
# |    value_loss           | 0.326       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 623          |
# |    iterations           | 39           |
# |    time_elapsed         | 128          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0062056584 |
# |    clip_fraction        | 0.0715       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0924       |
# |    n_updates            | 380          |
# |    policy_gradient_loss | 0.000311     |
# |    std                  | 0.866        |
# |    value_loss           | 0.318        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 618          |
# |    iterations           | 40           |
# |    time_elapsed         | 132          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0031581654 |
# |    clip_fraction        | 0.0359       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.127        |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00102     |
# |    std                  | 0.883        |
# |    value_loss           | 0.293        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 615          |
# |    iterations           | 41           |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0033025818 |
# |    clip_fraction        | 0.0348       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.119        |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000925    |
# |    std                  | 0.899        |
# |    value_loss           | 0.319        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 613         |
# |    iterations           | 42          |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.006445137 |
# |    clip_fraction        | 0.0693      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.186       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00536    |
# |    std                  | 0.902       |
# |    value_loss           | 0.304       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 613          |
# |    iterations           | 43           |
# |    time_elapsed         | 143          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0059952117 |
# |    clip_fraction        | 0.034        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.981        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.121        |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00114     |
# |    std                  | 0.902        |
# |    value_loss           | 0.288        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 613         |
# |    iterations           | 44          |
# |    time_elapsed         | 146         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.008252414 |
# |    clip_fraction        | 0.0865      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.123       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00396    |
# |    std                  | 0.89        |
# |    value_loss           | 0.305       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 613         |
# |    iterations           | 45          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.005570378 |
# |    clip_fraction        | 0.053       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.131       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00116    |
# |    std                  | 0.878       |
# |    value_loss           | 0.327       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 613         |
# |    iterations           | 46          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.006447655 |
# |    clip_fraction        | 0.0679      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.153       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00442    |
# |    std                  | 0.872       |
# |    value_loss           | 0.289       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 612         |
# |    iterations           | 47          |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.008330166 |
# |    clip_fraction        | 0.0957      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.097       |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00294    |
# |    std                  | 0.871       |
# |    value_loss           | 0.271       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 612          |
# |    iterations           | 48           |
# |    time_elapsed         | 160          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0047137886 |
# |    clip_fraction        | 0.0645       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.179        |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00326     |
# |    std                  | 0.88         |
# |    value_loss           | 0.345        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 611          |
# |    iterations           | 49           |
# |    time_elapsed         | 164          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0067815254 |
# |    clip_fraction        | 0.0766       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0985       |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00405     |
# |    std                  | 0.881        |
# |    value_loss           | 0.304        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 609         |
# |    iterations           | 50          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.008202419 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.125       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | 0.00188     |
# |    std                  | 0.874       |
# |    value_loss           | 0.322       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 608         |
# |    iterations           | 51          |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.006294233 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.179       |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00429    |
# |    std                  | 0.868       |
# |    value_loss           | 0.272       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 609         |
# |    iterations           | 52          |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.004273939 |
# |    clip_fraction        | 0.0585      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.108       |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00141    |
# |    std                  | 0.858       |
# |    value_loss           | 0.236       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 607         |
# |    iterations           | 53          |
# |    time_elapsed         | 178         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.005876362 |
# |    clip_fraction        | 0.0637      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.168       |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.000658   |
# |    std                  | 0.854       |
# |    value_loss           | 0.24        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 604         |
# |    iterations           | 54          |
# |    time_elapsed         | 182         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.005749191 |
# |    clip_fraction        | 0.0526      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.121       |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00162    |
# |    std                  | 0.827       |
# |    value_loss           | 0.221       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 604         |
# |    iterations           | 55          |
# |    time_elapsed         | 186         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.006287033 |
# |    clip_fraction        | 0.0665      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0765      |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00349    |
# |    std                  | 0.829       |
# |    value_loss           | 0.216       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 605          |
# |    iterations           | 56           |
# |    time_elapsed         | 189          |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0050500315 |
# |    clip_fraction        | 0.044        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.987        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.136        |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.00326     |
# |    std                  | 0.813        |
# |    value_loss           | 0.286        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 605          |
# |    iterations           | 57           |
# |    time_elapsed         | 192          |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.0061419774 |
# |    clip_fraction        | 0.039        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0638       |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.000297    |
# |    std                  | 0.804        |
# |    value_loss           | 0.248        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 603          |
# |    iterations           | 58           |
# |    time_elapsed         | 196          |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0058572832 |
# |    clip_fraction        | 0.0542       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0805       |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.0016      |
# |    std                  | 0.793        |
# |    value_loss           | 0.215        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 601          |
# |    iterations           | 59           |
# |    time_elapsed         | 200          |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 0.0066151205 |
# |    clip_fraction        | 0.0654       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.114        |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.00402     |
# |    std                  | 0.789        |
# |    value_loss           | 0.229        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 600          |
# |    iterations           | 60           |
# |    time_elapsed         | 204          |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# ...
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 551         |
# |    iterations           | 226         |
# |    time_elapsed         | 839         |
# |    total_timesteps      | 462848      |
# | train/                  |             |
# |    approx_kl            | 0.019824233 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.25       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0115      |
# |    n_updates            | 2250        |
# |    policy_gradient_loss | -0.00627    |
# |    std                  | 0.312       |
# |    value_loss           | 0.0308      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 551        |
# |    iterations           | 227        |
# |    time_elapsed         | 842        |
# |    total_timesteps      | 464896     |
# | train/                  |            |
# |    approx_kl            | 0.02574363 |
# |    clip_fraction        | 0.156      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.254     |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0215     |
# |    n_updates            | 2260       |
# |    policy_gradient_loss | -0.00193   |
# |    std                  | 0.31       |
# |    value_loss           | 0.035      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 551         |
# |    iterations           | 228         |
# |    time_elapsed         | 846         |
# |    total_timesteps      | 466944      |
# | train/                  |             |
# |    approx_kl            | 0.024832927 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.253      |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00625     |
# |    n_updates            | 2270        |
# |    policy_gradient_loss | -0.0044     |
# |    std                  | 0.312       |
# |    value_loss           | 0.0322      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 550         |
# |    iterations           | 229         |
# |    time_elapsed         | 851         |
# |    total_timesteps      | 468992      |
# | train/                  |             |
# |    approx_kl            | 0.027965385 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.249      |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.031       |
# |    n_updates            | 2280        |
# |    policy_gradient_loss | 0.00757     |
# |    std                  | 0.309       |
# |    value_loss           | 0.0487      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 550         |
# |    iterations           | 230         |
# |    time_elapsed         | 855         |
# |    total_timesteps      | 471040      |
# | train/                  |             |
# |    approx_kl            | 0.019337231 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.243      |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0435      |
# |    n_updates            | 2290        |
# |    policy_gradient_loss | 0.0017      |
# |    std                  | 0.309       |
# |    value_loss           | 0.0398      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 550        |
# |    iterations           | 231        |
# |    time_elapsed         | 859        |
# |    total_timesteps      | 473088     |
# | train/                  |            |
# |    approx_kl            | 0.01724512 |
# |    clip_fraction        | 0.159      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.233     |
# |    explained_variance   | 0.998      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.013      |
# |    n_updates            | 2300       |
# |    policy_gradient_loss | -0.00169   |
# |    std                  | 0.302      |
# |    value_loss           | 0.0294     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 550         |
# |    iterations           | 232         |
# |    time_elapsed         | 862         |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.029122634 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.228      |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00781     |
# |    n_updates            | 2310        |
# |    policy_gradient_loss | -0.00326    |
# |    std                  | 0.305       |
# |    value_loss           | 0.0306      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 550         |
# |    iterations           | 233         |
# |    time_elapsed         | 866         |
# |    total_timesteps      | 477184      |
# | train/                  |             |
# |    approx_kl            | 0.017434496 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.232      |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00542    |
# |    n_updates            | 2320        |
# |    policy_gradient_loss | -0.000729   |
# |    std                  | 0.305       |
# |    value_loss           | 0.0407      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 550         |
# |    iterations           | 234         |
# |    time_elapsed         | 870         |
# |    total_timesteps      | 479232      |
# | train/                  |             |
# |    approx_kl            | 0.019260796 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.234      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00499    |
# |    n_updates            | 2330        |
# |    policy_gradient_loss | -0.00228    |
# |    std                  | 0.306       |
# |    value_loss           | 0.0352      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 550          |
# |    iterations           | 235          |
# |    time_elapsed         | 874          |
# |    total_timesteps      | 481280       |
# | train/                  |              |
# |    approx_kl            | 0.0127803255 |
# |    clip_fraction        | 0.14         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.238       |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.023       |
# |    n_updates            | 2340         |
# |    policy_gradient_loss | 0.000155     |
# |    std                  | 0.308        |
# |    value_loss           | 0.0311       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 550         |
# |    iterations           | 236         |
# |    time_elapsed         | 878         |
# |    total_timesteps      | 483328      |
# | train/                  |             |
# |    approx_kl            | 0.033933185 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.241      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0136      |
# |    n_updates            | 2350        |
# |    policy_gradient_loss | -0.007      |
# |    std                  | 0.307       |
# |    value_loss           | 0.0324      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 550         |
# |    iterations           | 237         |
# |    time_elapsed         | 882         |
# |    total_timesteps      | 485376      |
# | train/                  |             |
# |    approx_kl            | 0.021830501 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.228      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.014       |
# |    n_updates            | 2360        |
# |    policy_gradient_loss | -0.00026    |
# |    std                  | 0.302       |
# |    value_loss           | 0.0452      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 550         |
# |    iterations           | 238         |
# |    time_elapsed         | 886         |
# |    total_timesteps      | 487424      |
# | train/                  |             |
# |    approx_kl            | 0.013311009 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.212      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000416    |
# |    n_updates            | 2370        |
# |    policy_gradient_loss | 0.000823    |
# |    std                  | 0.297       |
# |    value_loss           | 0.0345      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 550         |
# |    iterations           | 239         |
# |    time_elapsed         | 889         |
# |    total_timesteps      | 489472      |
# | train/                  |             |
# |    approx_kl            | 0.029817939 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.21       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00445     |
# |    n_updates            | 2380        |
# |    policy_gradient_loss | -0.00253    |
# |    std                  | 0.298       |
# |    value_loss           | 0.0318      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 549         |
# |    iterations           | 240         |
# |    time_elapsed         | 893         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.019625133 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.206      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00767     |
# |    n_updates            | 2390        |
# |    policy_gradient_loss | -0.000645   |
# |    std                  | 0.296       |
# |    value_loss           | 0.0356      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 549         |
# |    iterations           | 241         |
# |    time_elapsed         | 897         |
# |    total_timesteps      | 493568      |
# | train/                  |             |
# |    approx_kl            | 0.025965609 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.195      |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0133      |
# |    n_updates            | 2400        |
# |    policy_gradient_loss | -0.00215    |
# |    std                  | 0.293       |
# |    value_loss           | 0.0524      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 549        |
# |    iterations           | 242        |
# |    time_elapsed         | 901        |
# |    total_timesteps      | 495616     |
# | train/                  |            |
# |    approx_kl            | 0.01755923 |
# |    clip_fraction        | 0.162      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.194     |
# |    explained_variance   | 0.998      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00299   |
# |    n_updates            | 2410       |
# |    policy_gradient_loss | 0.00669    |
# |    std                  | 0.295      |
# |    value_loss           | 0.0366     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 549         |
# |    iterations           | 243         |
# |    time_elapsed         | 905         |
# |    total_timesteps      | 497664      |
# | train/                  |             |
# |    approx_kl            | 0.022914577 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.201      |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.03        |
# |    n_updates            | 2420        |
# |    policy_gradient_loss | -0.00019    |
# |    std                  | 0.297       |
# |    value_loss           | 0.0425      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 549         |
# |    iterations           | 244         |
# |    time_elapsed         | 909         |
# |    total_timesteps      | 499712      |
# | train/                  |             |
# |    approx_kl            | 0.023218567 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.194      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00665    |
# |    n_updates            | 2430        |
# |    policy_gradient_loss | -0.00517    |
# |    std                  | 0.29        |
# |    value_loss           | 0.0302      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 549         |
# |    iterations           | 245         |
# |    time_elapsed         | 912         |
# |    total_timesteps      | 501760      |
# | train/                  |             |
# |    approx_kl            | 0.016700175 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.166      |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0286     |
# |    n_updates            | 2440        |
# |    policy_gradient_loss | -0.00283    |
# |    std                  | 0.281       |
# |    value_loss           | 0.0306      |
# -----------------------------------------
# Training complete!
# Generating training metrics plots...
# Model saved!
